# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
EDA_data = pd.read_csv('Train2.csv')

# %%
EDA_data.head()
# Out:
#   Gender  Age  Education_Level Relationship_Status                       Unit  \
# 0      F   42                4             Married                         IT
# 1      M   24                3              Single                  Logistics
# 2      F   58                3             Married                    Quality
# 3      F   26                3              Single  Human Resource Management
# 4      F   31                1             Married                  Logistics
#
#   Decision_skill_possess  Time_of_service  Time_since_promotion  growth_rate  \
# 0             Conceptual              4.0                     4           33
# 1             Analytical              5.0                     4           36
# 2             Conceptual             27.0                     3           51
# 3             Behavioral              4.0                     3           56
# 4             Conceptual              5.0                     4           62
#
# ...

# %%
sns.heatmap(EDA_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.pairplot(EDA_data,x_vars=EDA_data.columns,y_vars='Attrition_rate')

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='Gender',hue='Unit',data=EDA_data)

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Pay_Scale',hue='Gender',data=EDA_data)

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='Relationship_Status',hue='Work_Life_balance',data=EDA_data)

# %%
sns.lineplot(x='Decision_skill_possess',y='Work_Life_balance',hue='Gender',data = EDA_data)

# %%
sns.lineplot(x='Time_of_service',y='growth_rate',data = EDA_data)

# %%
EDA_data['Time_since_promotion'].plot.hist()

# %%
sns.boxplot(x=EDA_data.Education_Level,y=EDA_data.Pay_Scale)
